# %% [markdown]
# # Frequency Analysis using NTLK
#
# NLTK, the natural language processing toolkit for Python, provides a number of ways to analyze text.

# %%
import nltk
from nltk.probability import FreqDist
from nltk.corpus import gutenberg

moby_dick=gutenberg.words('melville-moby_dick.txt')

# %%
### All the words in the text?

fdist = FreqDist(moby_dick)
fdist.keys() # Ordered - DESC freq
# Out:
# dict_keys(['infinity', 'entrances', 'courting', 'discourse', 'plumes', 'corkscrew', 'Fishery', 'good', 'whales', 'lieutenants', 'confabulations', 'blasting', 'daintiest', 'curbstone', 'correct', 'greedy', 'emptied', 'hopes', 'selves', 'breaks', 'cooked', 'construction', 'striding', 'prouder', 'gazing', 'BLACKSMITH', 'flowing', 'ventricles', 'blankets', 'Massachusetts', 'quiver', 'married', 'examples', 'civilly', 'Splice', 'Rat', 'eating', 'moon', 'personally', 'Dinner', 'although', 'banteringly', 'bloodiest', 'oakum', 'ferociousness', 'directly', 'insect', 'shamble', 'claim', 'wrath', 'braver', 'clasped', 'wived', 'modes', 'cheap', 'constrained', 'reference', 'uninvitedly', ');--', 'putting', 'sailmakers', 'Straightway', 'tattooed', 'gurgling', 'Quakerism', 'tilted', 'retires', 'ominous', 'skewers', 'wandereth', 'partners', 'shouted', 'cutlet', 'bare', 'fathom', 'Gods', 'brown', 'unvexed', 'artificialness', 'filaments', 'gardenny', 'rule', 'bread', 'HORRID', 'connecting', 'beholder', 'eels', 'Indeed', 'meanest', 'indefiniteness', 'arching', 'motion', 'roughly', 'painfully', 'skulled', 'umbilical', 'subdued', 'feelings', 'salutes', 'hones', 'Mixed', 'accounting', 'turtle', 'answered', 'famous', 'consorted', 'housekeepers', 'crucifixion', 'poverty', 'spit', 'resembled', 'scatter', 'habitatory', 'reg', 'glee', 'Pequod', 'affronted', 'eleven', 'mumblings', 'suppressed', 'hereafters', 'snakes', 'him', 'blades', 'steep', 'lost', 'Continents', 'Reckon', 'Sail', 'storms', 'bearer', 'ROSE', 'Temperance', 'remembrance', 'Aldrovandus', 'Charlemagne', 'determining', 'Hudson', 'Desmarest', 'bat', 'overspread', 'leach', 'brotherhood', 'sultan', 'marlingspike', 'bedwards', 'fireside', 'carpet', 'resort', 'PREFACE', 'slices', 'shiverings', 'ascribed', 'wheezing', 'shock', 'wail', 'increased', 'stowage', 'razeed', 'shops', 'steadily', 'cascading', 'Glory', 'fitness', 'forsaken', 'duck', 'mounting', 'divide', 'ply', 'wrangling', 'attested', 'Mesopotamian', 'attends', 'painful', 'decoration', 'enormousness', 'chamois', 'dampness', 'grog', 'southern', 'thwart', 'acquainted', 'places', 'reliably', 'Enderbys', 'died', 'horses', 'feelingly', 'falls', 'fadest', 'corresponds', 'immersed', 'circumference', 'Camel', 'fork', 'pennons', 'Mistress', 'lightly', 'gaunt', 'Spout', 'Sagittarius', 'Babylon', 'mistrust', 'resemblance', 'militant', 'issuing', 'JOURNAL', 'cosy', 'sixth', 'whaleship', 'pupils', 'DICTIONARY', 'summers', 'hypo', 'cloak', 'metallic', 'mode', 'OPENING', 'Considering', 'chemistry', 'unsafe', 'Dunfermline', 'circular', 'unset', 'sighting', 'Frankfort', 'slobgollion', 'verbalists', 'embodiment', 'foundation', 'Whalemen', 'ejaculates', 'DRYDEN', 'fear', 'hinges', 'eludes', 'accommodate', 'blockhead', 'dabs', 'preventer', 'BEALE', 'justice', 'crotch', 'paused', 'woman', 'forbids', 'BRACE', 'territories', 'symmetrically', 'bulkhead', 'portraits', 'Forward', 'sail', 'solicitously', 'pursuing', 'colours', 'unsuffusing', 'expressing', 'timid', 'partly', 'lashes', 'manoeuvred', 'skeletons', 'Tolland', 'unfrequently', 'appreciative', 'burrower', 'inventive', 'sways', 'wild', 'yesterday', 'Christians', 'flowed', '1729', 'wooing', 'inquiry', 'Preserving', 'Opposite', 'glanced', 'require', 'Himself', 'cures', 'untrodden', 'enactment', 'injured', 'bird', 'Spain', 'apron', 'rules', 'scores', 'core', 'Corlears', 'prow', 'bits', 'musk', 'more', 'coaches', 'thirstily', 'modifies', 'perdition', 'flowery', 'Laws', 'philosophies', 'disabled', 'Hawaiian', 'scramble', 'Rig', 'peels', 'probably', 'greeted', 'Flounders', 'Slip', 'historical', 'walnut', 'condescension', 'forked', 'breeding', 'seaweed', 'intended', 'drunken', 'atheistical', 'socks', 'pelisse', 'Wrinkled', 'respecting', 'questioned', 'taking', 'Jumped', 'knowledge', 'foal', 'average', 'chair', 'libertines', 'reminding', 'Hook', 'honour', 'brazen', 'Ports', 'chowders', 'survey', 'parting', 'map', 'unskilful', 'Ethiopian', 'stockinged', 'sparks', 'toadstools', 'enkindling', 'membranes', 'snooze', 'c ...

# %%
### How many occurrences of a word?

fdist = FreqDist(moby_dick)
fdist['whale'] # 906
# Out:
# 906
