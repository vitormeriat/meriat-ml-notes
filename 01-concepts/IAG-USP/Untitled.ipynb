# %%
import pyodbc
from datetime import datetime, timedelta

# %%
server = "meriat.database.windows.net"
database = "intents"
username = "meriat"
password = "q1w2e3Q!W@E#"

driver= '{ODBC Driver 13 for SQL Server}'
cnxn = pyodbc.connect('DRIVER='+driver+';PORT=1433;SERVER='+server+';PORT=1443;DATABASE='+database+';UID='+username+';PWD='+ password)

# %%
query = 'SELECT DISTINCT Reference FROM [dbo].[TranscriptionTexts]'

# %%
cursor = cnxn.cursor()
cursor.execute(query)
references = cursor.fetchone()

#count = 1
aList = []
while references:
    #print(str(count) + " - " + str(references[0]))
    aList.append(references[0])
    #count += 1
    references = cursor.fetchone()
    
print(len(aList))
print(aList[len(aList)-1])
# Out:
# 13882
# CB67A3D0-05FA-11E8-A74A-4FD6287B4CE0

# %%
cursor = cnxn.cursor()
cursor.execute("SELECT tt.Id, tt.Reference, tt.Text, tt.Speaker FROM [dbo].[TranscriptionTexts] AS tt WHERE tt.Reference = '56A6E060-05FA-11E8-B97C-7FF5EE0D6EE0'")
row = cursor.fetchone()
while row:
    print (str(row[3]) + " - " + str(row[2]))
    row = cursor.fetchone()
# Out:
# 2 - central do corretor  Viviane boa tarde .
# 1 - boa tarde Viviane meu nome é Nádia
# 2 - oi Nádia
# 1 - tudo bom .
# 2 - tudo bem   tô
# 1 - querendo   solicitar    uma   boleta   com você
# 2 - qual é o CPF do cliente se
# 1 - zero um nove  cinco dois oito  quatro sete cinco   três oito     sessenta e nove      seis oito  seis um sete cinco cinco três
# 2 - demais mas
# 1 - eu  vou tomar um quatro  zero cinco  nove um   seis  nove  sete cinco sete  dois  o José Romero .  eu não sei se ainda tá já  você já tá gerado aqui que   ele quer pagar antes  da data  .  eu acho que é final de mês .
# 2 - eu só não tenho como alterar  se já  existe um boleto aí  Caio  bota   o leite  amanhã  viu  que tá aqui
# 1 - alisson
# 2 - amiga confirma  o  CNPJ é sete
# 1 - dois seis sete dois seis dois nove um meia  nove  três   e a Susi  pra ver  se   vezes  hoje   dois dois quatro quatro .
# 2 - só um minuto tá                                                                                                                ô primeiro é Cláudia né .
# 1 - beijos . te adoro  você
# 2 - estiver    aqui eu tenho que tá em aberto  .  puder me assar um peixe é Bele
# 1 - lição   liga duzentos reais
# 2 - isso        ela não tem nada em aberto  .
# 1 - não  ela não tem o que eu queria saber se o próximo  já tem como visualizar
# 2 - essa   boleta
# 1 - que eu acho que  final do mês
# 2 - é
# 1 - porque  eu não vejo a luz ou não mas eu queria ver se você visualiza
# 2 - vencimento dela aqui   desse mês   tava dia sete né . aí  deixa  sua consulta que  seu  outro tá disponível    o de fevereiro não tá gerada  não mas aí eu posso  encaminhar   pra você
# 1 - um caminho pra mim por favor  que eles vão viajar pra fora do país  quero deixar já pago .
# 2 - aí eu vou embora dia sete fevereiro tá .
# 1 - eles    tão
# 2 - mandando   no  seu e-mail mesmo  .
# 1 - beijo  mano  meu cama   pelos atos dela
# 2 - LL Ribeiro e Ferreira
# 1 - meia    benefícios quando eu mando  um e-mail por fora  corretor com quem que eu vejo  você já teve  retorno porque eu ainda não recebi retorno .
# 2 - eu passei aqui pra você mas não   aumente   o retorno é por e-mail mesmo .
# 1 - mas já foi  cinco dias depois
# 2 - cinco dias úteis é pra iniciar a tratativa do e-mail  . aí dependendo do que você solicita  ele  gera um outro prazo    de   cinco  dias em até cinco dias após  recebido . a gente tem que  iniciar a tratativa dele
# 1 - entendeu  .  então vamos  filho  de  Deus  isso aí
# 2 - depende  do  que você pediu  para  se você pediu   um boleto por e-mail  até cinco dias a gente tem pra iniciar lá pra identificar o seu pedido  e aí  se a um boleto a gente já gera  na hora depende  que você
# 1 - perde não  sua reclamação  no    qual ela só que      ela casou  que tem uma premiação em novembro e  eu tava dentro   dá pra minha  sala e a   minha gerente  não  me  deu
# 2 - a então  possa vir aqui  pra você .  você já iniciou a tratativa    outra é a Sônia né .
# 1 - isso
# 2 - daí não     é pra   lembrar   que
# 1 - a mesma coisa
# 2 - só  que o dela é  Cristina .
# 1 - o    de Deus  eu não ouço sua      voz agora
# 2 - faltam  dois aí   que  já
# 1 - vi
# 2 - aqui com alguém  né . ela tem dois vencimentos  um dia
# 1 - cinco
# 2 - e o outro  dia primeiro
# 1 - pra mandar os
# 2 - dois
# 1 - pra depois você manda  separado   desculpa  pela      atender liga o tempo aí hoje  tá como
# 2 - olha  tá bem quente hoje  .
# 1 - tava
# 2 - tava uma chuva danada mas agora  que a mãe já desde ontem  ante ontem a tarde  tava bom  aí ontem  o tempo já  ficou hoje  o dia já ficou o sol
# 1 - sol
# 2 - e hoje tá de novo mas fala  que vai mandar   já tá
# 1 - aqui desde ontem que fala  que vai ter chuva muita chuva
# 2 - mais  raiva  eu ainda
# 1 - não tô aqui  abafado  muito abafado
# 2 - aqui  na época   que tava chovendo  tava chovendo mas  também tava sem super abafado  onde
# 1 - você tá amor  desculpa mas  você
# 2 - não melhorava em nada né .
# 1 - que eu tenho alergia  minha filha .
# 2 - liga     logo é a
# 1 - minha filha  também  ela ficou  mal   bola  .
# 2 - imagina  aí  aqui que a gente tá assim   hoje o tempo tá bem quente  tá bem e tá limpo mas não tá com   cara de que vai chover não
# 1 - o  vou tá por aí na Drogasil  lá
# 2 - né . ah não esquece
# 1 - não
# 2 - vem  buscar aqui
# 1 - por favor
# 2 - fala aí meu  pelo menos conheceu  ano passado tá lá
# 1 - como lá
# 2 - agora você  vai morrer    .  você quer  ver  alguém  pra ir né   .   mas  eu tô
# 1 - perto   esse ano aí por favor     que eu   ando pensando nisso .
# 2 - olha eu nunca fui na cerimônia enfim mas eu vejo  as premiações aqui  nossa é uma vergonha   glamourosa né .
# 1 - por isso  perfeito  esse  telefone    celebridade .
# 2 - eu
# 1 - falar muito .
# 2 - e aí vai quem é que a gente vai ver o anel  lá apresentando o ralo
# 1 - eu
# 2 - tirei
# 1 - foto
# 2 - amanhã  vem    bacana  inúmeras   não
# 1 - e  engraçado que quando ele chegou de tarde  eu ia sair do  motel pra ele  não sei onde  ele tava na recepção     toda com  meu colega que vai encostar aqui  vou  ficar aqui pra      foto  ele
# 2 - precisa
# 1 - de alguma coisa você vai comprar coisa  faz um monte
# 2 - de
# 1 - direito  muito boa muito boa festa   tudo tudo   tudo bom
# 2 - é tudo muito do amoroso né .
# 1 - eu tô muito organizado   mas  você não vê se vale  nada . você procura   por
# 2 - mais  que você procure  você não encontrou
# 1 - mas   até  eu achei engraçado  que quando a gente  sai   dá  mais um vale   ouro  só de noite  que já é tarde já   não dá mais agora domingo né . aí já sai da boate lá de fora tem  um painel com todos os nomes de  horário de voo e  horário que a van vai pegar  as pessoas
# 2 - porque vocês ainda vem no do vão embora no domingo ainda
# 1 - no domingo hoje
# 2 - tá  perfeito eu
# 1 - sei que você nem se preocupa com isso
# 2 - porque  nada . eu vi que tem pessoas que ainda aproveita o restinho da noite  nós vai dar um passeio por ali na  na  zona sul      ainda  vem malhar  eu marquei
# 1 - tem um passeio no sábado  que a gente  escolhe  pra  levar   os roteiro  ou eu    ir pro     jogo  amanhã né .
# 2 - a tá  mulher  que daí   a gente dá o dia até daqui né   .
# 1 - então a gente foi lá no sábado de manhã     eu  achei interessante que eu comentei  também . você
# 2 - entrou
# 1 - no ônibus aí ele já chegou em capa de chuva  tão  lindo
# 2 - nessa
# 1 - capa de chuva porque vai que chove
# 2 - tá   já tá preparada .
# 1 - pensou em tudo tudo tudo  tudo
# 2 - daqui pro museu  né   a gente vai até  bem pertinho    de  velho  tem ela
# 1 - não  não  temos  o ônibus
# 2 - tá
# 1 - já     tava na porta do hotel  e  já
# 2 - deixava  lá  .
# 1 - mas é muito curto bem    porque  eu acho que a gente  umas  nove  aí   uma hora já  tem     evento  aí  como a minha
# 2 - cara     rapidinho  no painel      e o Rafa  aí
# 1 - no
# 2 - evento é no
# 1 - salão . salão de beleza de tarde  o dia todo bem  só  quando eu pra marcar  meia hora  já tava lotado só que  é na hora de  medir   depois vou ficar aqui muito pouco de mês que eu pego  a noite .
# 2 - ai eu vou comprar não
# 1 - morreu   botar no cabelo    gel que fica  o Ariel  tava  pronta  .
# 2 - aproveitou bastante né .
# 1 - aproveitei todos os minutos
# 2 - agora já tem experiência no final do ano que vem já de chamar assim que chegar   já  marcar logo
# 1 - pro
# 2 - último horário né .
# 1 - então o   verdade . quando  chegar o  jogo tá bom .
# 2 - vê  se  deu alguma coisa  lá do Antônio .  ele tem o total de contribuição de cento  quarenta e sete quatro oito Maria Helena   é
# 1 - né .
# 2 - ele tem a  outubro novembro  dezembro .
# 1 - manda   pra mim  porque  ele   tava no sítio
# 2 - mas
# 1 - eu não tô  não  tô lhe  . mandei   junto   vamos    vamos
# 2 - botar
# 1 - dia quinze
# 2 - só
# 1 - que você mandou  também separado  mas
# 2 - já   já mandei separar   o  vencimento é dia  cinco e  outro  dia primeiro de fevereiro .
# 1 - então
# 2 - tá .
# 1 - desejo    que você se  quiser eu já gerei duas vezes e não pagou   está  bem  .   tava no sítio    você foi comeu   bolo
# 2 - ontem eu tava lá em baixo  lá
# 1 - no bola né  não
# 2 - tá   tava bem animadinha o pessoal lá em baixo  depois a gente subiu porque  a gente ficou lá   de quatro e meia até as seis e meia  agora que terminou . e  depois a gente volta pra cá
# 1 - quando eu liguei de tarde  aí  dizer  que tava o sistema tava  operando alguma coisa assim
# 2 - tá é a   tá lá em baixo .
# 1 - aí depois eu liguei   consegui falar com  o número    ela . ela disse que tava lá em baixo comemorando  o
# 2 - porque até esse horário fica  eu
# 1 - a
# 2 - Isabele    a Kelly é   Cris é   Antônio .  antônio vai embora  seis horas seis e  fala não é
# 1 - hora  .   eu  queria saber da comigo porque ele    ontem  ele disse que quer me conhecer  eu ele
# 2 - vai aí na agenda
# 1 - onde
# 2 - tá  é a Neide
# 1 - eu vou  escrever     a bolsa    que veio   era  e eu  papai ligar e   viria  pra me
# 2 - levar .
# 1 - eu sou  eu
# 2 - Cleide     agora   pra    nele   era  lembra  da
# 1 - pessoa  que não sei quem foi ela disse que    você deixou pra  que o Facebook pra ver que  você ia levar pra
# 2 - a gente acostumar de sanar vários corretores não fez quem falou  que   você não
# 1 - não  lembro  não me adicionou      eu tô indo
# 2 - a Goiânia
# 1 - do seu lado     o celular        .    eu  achei que ela ia mandar um convite mas eu   já não sei ela mandou eu não vi  também o
# 2 - seu  fica como a Nádia   mesmo né  .
# 1 - da Marilu
# 2 - acho  que você  tinha as    a para  fazer
# 1 - as fotos  do  Davi ou
# 2 - então nesse aqui não deixa eu falar
# 1 - o  leilão   da Maria dos Santos . se você é Amanda   Maria Mongeral    .  estamos agora mas  eu não    eu não recebi
# 2 - a foto tá do galo  .
# 1 - não deixa  ver como é que tá
# 2 - aquilo     mas  eu não   gerar um cabelo curtinho .
# 1 - eu
# 2 - achei
# 1 - eu tô dormindo   vou pra  Rosa né  .
# 2 - eu ia   levar a   namorada  segurando alguma coisa do galo vai ganhar
# 1 - é você  e
# 2 - essa
# 1 - dor é rapidinho me atende
# 2 - rapidinho viu
# 1 - somos  amigas  .
# 2 - eu  vou mandar  tua falta aqui no grupo do pessoal que quando a gente  fala com   corretor   de cena não sei se a gente manda aqui pra gente  pra    gente tá curioso é que a gente fala sempre
# 1 - largou      vocês  sairam   eu quero
# 2 - saber como que é a   o  rosto  a gente queria uma imagem   de ir com a  Helena é nada daquilo que a gente vai de novo .
# 1 - então foi tão engraçado   . olha  minha
# 2 - namoradinha    bem bonitona
# 1 - encontrou   com
# 2 - Tadeu .
# 1 - posso passar
# 2 - o  galo  esse é do galo né    . não precisa nem ir  no salão  né botou e ela ficou boa    .
# 1 - teve   o  gel
# 2 - aí   sai daí
# 1 - cinquenta  fala  baixo .
# 2 - aí  eu aproveitou o tempo com outras coisas não precisa nem gastar tempo  no no salão .
# 1 - eu ia ficar de meio-dia tá de   cabelo  arrumado  e  toda arrumadinha   me  batia  aonde  eu tava  não
# 2 - sem poder fazer  nada .
# 1 - eu não fiz  maior    vai  lá pra      vou embora  e
# 2 - eu também dou todos os momentos
# 1 - trata com suas coisas .
# 2 - tá certíssima
# 1 - agora
# 2 - aí  você
# 1 - recebeu      meu  e-mail . você vê  aí se tem retorno . tem como
# 2 - pegar  é parei  você mandou do L E L L R   .
# 1 - eu acho que a mãe mandou
# 2 - já  o outro lado
# 1 - da  avenida
# 2 - Nadine  é que
# 1 - dormir  doze  @ Hotmail .com
# 2 - Hotmail     deixa eu ver se já tem alguma coisa aqui    você lembra  quando mandou
# 1 - eu acho que  mandei quarta-feira passada  foi dia  dia
# 2 - três  não foi de alguém um e-mail aqui  mais recente é dia dois .
# 1 - então foi assim
# 2 - que
# 1 - fala  dó   você ver o   corpo do e-mail .
# 2 - vou ver agora    .
# 1 - atenda    pensa  que eu mandei a  noite
# 2 - porque o inicio desse  e-mail aqui   você vai pedir a transferência da sua unidade de Aracaju pra Maceió
# 1 - e   depois tem o reclamando
# 2 - porque
# 1 - você não  foi  em novembro  e eu   e minha  meu código  . em dezembro  não tem como receber a premiação    pro Marcelo    oi Rosimeire
# 2 - aqui  tá falando  que a transferência foi concluida
# 1 - neste
# 2 - confirmar que o
# 1 - que  que é o  Nivaldo  seu tio
# 2 - Daniel  .  esqueci   a minha  só que não não tem  uma outra ainda  pra vocês virem dar  certo
# 1 - não    .  não vai ficar ou melhor fui   viajar e vai ficar aqui  não  atendendo em casa . mas só como  eu vou   eu ando muito passei   a noite  aí eu comecei namorar   com  ele me mostrou  eu preciso falar com ele não puder eu levo a vontade  quando  quiser na
# 2 - farra
# 1 - aí é a Juranda    que ficou meia   com raivinha   e aí  bicho que eu procurasse  a    medida das minhas mediações   no seu    oi assim   também   eu vou ver se é assim mesmo que funciona  . eu não  acho que  assim que for provisionado porque   o dinheiro não posso eu não tava lá .
# 2 - fiquei lá  eles vão pedir pra você  procurar aqui  né . a outra
# 1 - coisa eu falei com Rafael lá com a gerente não não   nada não tem como será que ele vem ter     com você  aí     tô    ligando porque no  dia da reunião não foi  alguma  reunião com ela . ela   mandou   uma   estação   comigo é meu colega que perguntou  e a  primeira chamada    ela vem pegar quando  elas  não ligar  aquela  pra fazer lá em Maceió
# 2 - eu
# 1 - ligo tá .   não vou desculpe  não .
# 2 - deixa eu ver aqui  porque eu tenho uma solicitação feita aqui com    a  Dani que  abriu   mas deixa eu confirmar aqui o
# 1 - valor  não é nem grande  não acredita  mais   direito hoje  gente corre pra vender
# 2 - mas essa  direita  a ou você mandou o e-mail  mas a a é   teve um registro aqui  só que  essa  solicitação    tem que se tratava direto na unidade mesmo . deixa eu ver aqui só
# 1 - que não tem  .
# 2 - então  só que agora  já não tem mais a unidade  né .   deixa eu só confirmou  a gente
# 1 - deve passar pra  gerente que tava aqui
# 2 - né . provavelmente . mas eu preciso confirmar  guarda só um minutinho tá . mais tarde tá
